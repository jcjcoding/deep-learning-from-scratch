# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.models import alexnet
from torchvision.models import AlexNet_Weights
import time
import os
import matplotlib.pyplot as plt
import numpy as np
import random
import torchvision.datasets.stl10 as stl10

# %%
# -------------------------- 1. 配置设备 --------------------------
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"使用设备：{device}")  # 正常输出"cuda:0"
# Out:
# 使用设备：cuda:0

# %%
# -------------------------- 2. 数据加载与预处理 --------------------------
# 自定义STL10类，跳过原始压缩包的完整性校验（核心修改）原来是下载，然后class STL10NoCheck(datasets.STL10):
    def _check_integrity(self):
        # 强制返回True，告诉torchvision"数据集是完整的"，跳过压缩包校验
        return True

# STL-10原始图像尺寸96×96，需放大到227×227（AlexNet输入尺寸）
# 训练集预处理：放大+数据增强（小数据集必须增强防过拟合）
train_transform = transforms.Compose([
    transforms.Resize(227),  # 96×96→227×227（放大，保持比例）
    transforms.RandomHorizontalFlip(p=0.5),  # 50%水平翻转
    transforms.RandomRotation(10),  # 随机旋转±10度
    transforms.ToTensor(),
    # STL-10常用标准化参数（像素值从0-1→-1到1，更稳定）
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# 验证集预处理：仅放大和标准化（无增强，保证评估稳定）
val_transform = transforms.Compose([
    transforms.Resize(227),  # 同样放大到227×227
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# 加载STL-10数据集（用自定义类，跳过校验）
data_root = "./data"  # 与你的data文件夹路径一致

# 训练集（本地加载，关闭下载，用自定义类跳过校验）
train_dataset = STL10NoCheck(
    root=data_root,
    split='train',
    download=False,  # 已手动准备数据，无需下载
    transform=train_transform
)

# 测试集（本地加载，关闭下载，用自定义类跳过校验）
val_dataset = STL10NoCheck(
    root=data_root,
    split='test',
    download=False,  # 已手动准备数据，无需下载
    transform=val_transform
)


# 数据加载器（优化num_workers，避免Windows多线程问题）
batch_size = 16  # 4060 8GB显存足够
# Windows系统建议num_workers=0（避免多线程报错），Linux/macOS可用4
num_workers = 0 if os.name == 'nt' else 4

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练集打乱
    num_workers=num_workers
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,  # 验证集不打乱
    num_workers=num_workers
)

# %%
# -------------------------- 3. 定义模型（适配STL-10的10个类别） --------------------------
# STL-10是10类，修改输出层为num_classes=10
model = alexnet(weights=None, num_classes=10)
model = model.to(device)  # 移到GPU

# %%
# -------------------------- 4. 定义损失函数、优化器（适配小数据集） --------------------------
criterion = nn.CrossEntropyLoss()  # 分类任务标配

# 优化器：STL-10数据量小（5000张），初始学习率调低到0.001（避免快速过拟合）
optimizer = optim.SGD(
    model.parameters(),
    lr=0.001,  # 比ImageNet的0.01小，适合小数据集
    momentum=0.9,  # 保持动量加速收敛
    weight_decay=5e-4  # 权重衰减防过拟合
)

# 学习率调度器：每20个epoch衰减一次（STL-10训练快，衰减频率稍高）
lr_scheduler = optim.lr_scheduler.StepLR(
    optimizer,
    step_size=20,  # 每20个epoch衰减
    gamma=0.1
)

# %%
# -------------------------- 5. 训练与验证循环 --------------------------
num_epochs = 60  # STL-10数据少，60个epoch足够（比ImageNet的90少）
best_acc = 0.0
save_path = "./alexnet_stl10.pth"  # 模型保存路径（明确标注STL-10）

for epoch in range(num_epochs):
    # 训练阶段
    model.train()
    running_loss = 0.0
    start_time = time.time()

    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()  # 清空梯度
        outputs = model(inputs)  # 前向传播
        loss = criterion(outputs, labels)  # 计算损失
        loss.backward()  # 反向传播
        optimizer.step()  # 更新参数

        # 每50个batch打印一次损失（STL-10的batch数少，50更合适）
        running_loss += loss.item()
        if (i + 1) % 50 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{i+1}/{len(train_loader)}], Loss: {running_loss/50:.4f}")
            running_loss = 0.0

    # 更新学习率
    lr_scheduler.step()
    train_time = time.time() - start_time
    print(f"Epoch {epoch+1} 训练耗时：{train_time:.2f}秒")

    # 验证阶段
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_acc = 100 * correct / total
    print(f"Epoch {epoch+1} 验证准确率：{val_acc:.2f}%")

    # 保存最佳模型
    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), save_path)
        print(f"最佳模型已保存（准确率：{best_acc:.2f}%）")

print("训练完毕！")
print(f"最终最佳验证准确率：{best_acc:.2f}%")
# Out:
# Epoch [1/60], Batch [50/313], Loss: 2.3027
# Epoch [1/60], Batch [100/313], Loss: 2.3019
# Epoch [1/60], Batch [150/313], Loss: 2.3035
# Epoch [1/60], Batch [200/313], Loss: 2.3030
# Epoch [1/60], Batch [250/313], Loss: 2.3035
# Epoch [1/60], Batch [300/313], Loss: 2.3028
# Epoch 1 训练耗时：64.56秒
# Epoch 1 验证准确率：15.70%
# 最佳模型已保存（准确率：15.70%）
# Epoch [2/60], Batch [50/313], Loss: 2.3024
# Epoch [2/60], Batch [100/313], Loss: 2.3023
# Epoch [2/60], Batch [150/313], Loss: 2.3025
# Epoch [2/60], Batch [200/313], Loss: 2.3024
# Epoch [2/60], Batch [250/313], Loss: 2.3024
# Epoch [2/60], Batch [300/313], Loss: 2.3022
# Epoch 2 训练耗时：61.12秒
# Epoch 2 验证准确率：13.43%
# Epoch [3/60], Batch [50/313], Loss: 2.3015
# Epoch [3/60], Batch [100/313], Loss: 2.3017
# Epoch [3/60], Batch [150/313], Loss: 2.3018
# Epoch [3/60], Batch [200/313], Loss: 2.3012
# Epoch [3/60], Batch [250/313], Loss: 2.3015
# Epoch [3/60], Batch [300/313], Loss: 2.3014
# Epoch 3 训练耗时：57.49秒
# Epoch 3 验证准确率：10.96%
# Epoch [4/60], Batch [50/313], Loss: 2.3000
# Epoch [4/60], Batch [100/313], Loss: 2.3000
# Epoch [4/60], Batch [150/313], Loss: 2.2991
# Epoch [4/60], Batch [200/313], Loss: 2.2997
# Epoch [4/60], Batch [250/313], Loss: 2.2975
# Epoch [4/60], Batch [300/313], Loss: 2.2968
# Epoch 4 训练耗时：60.75秒
# Epoch 4 验证准确率：12.39%
# Epoch [5/60], Batch [50/313], Loss: 2.2931
# Epoch [5/60], Batch [100/313], Loss: 2.2886
# Epoch [5/60], Batch [150/313], Loss: 2.2863
# Epoch [5/60], Batch [200/313], Loss: 2.2705
# Epoch [5/60], Batch [250/313], Loss: 2.2661
# Epoch [5/60], Batch [300/313], Loss: 2.2537
# Epoch 5 训练耗时：64.73秒
# Epoch 5 验证准确率：15.41%
# Epoch [6/60], Batch [50/313], Loss: 2.1786
# Epoch [6/60], Batch [100/313], Loss: 2.1701
# Epoch [6/60], Batch [150/313], Loss: 2.1431
# Epoch [6/60], Batch [200/313], Loss: 2.1398
# Epoch [6/60], Batch [250/313], Loss: 2.1161
# Epoch [6/60], Batch [300/313], Loss: 2.1184
# Epoch 6 训练耗时：63.59秒
# Epoch 6 验证准确率：24.09%
# 最佳模型已保存（准确率：24.09%）
# Epoch [7/60], Batch [50/313], Loss: 2.0304
# Epoch [7/60], Batch [100/313], Loss: 2.0132
# Epoch [7/60], Batch [150/313], Loss: 1.9650
# Epoch [7/60], Batch [200/313], Loss: 1.9237
# Epoch [7/60], Batch [250/313], Loss: 1.8709
# Epoch [7/60], Batch [300/313], Loss: 1.9553
# Epoch 7 训练耗时：60.72秒
# Epoch 7 验证准确率：25.95%
# 最佳模型已保存（准确率：25.95%）
# Epoch [8/60], Batch [50/313], Loss: 1.8670
# Epoch [8/60], Batch [100/313], Loss: 1.8480
# Epoch [8/60], Batch [150/313], Loss: 1.8492
# Epoch [8/60], Batch [200/313], Loss: 1.7969
# Epoch [8/60], Batch [250/313], Loss: 1.8012
# Epoch [8/60], Batch [300/313], Loss: 1.8161
# Epoch 8 训练耗时：59.43秒
# Epoch 8 验证准确率：28.84%
# 最佳模型已保存（准确率：28.84%）
# Epoch [9/60], Batch [50/313], Loss: 1.7161
# Epoch [9/60], Batch [100/313], Loss: 1.7389
# Epoch [9/60], Batch [150/313], Loss: 1.7625
# Epoch [9/60], Batch [200/313], Loss: 1.7466
# Epoch [9/60], Batch [250/313], Loss: 1.6751
# Epoch [9/60], Batch [300/313], Loss: 1.7124
# Epoch 9 训练耗时：64.05秒
# Epoch 9 验证准确率：32.50%
# 最佳模型已保存（准确率：32.50%）
# Epoch [10/60], Batch [50/313], Loss: 1.6949
# Epoch [10/60], Batch [100/313], Loss: 1.6646
# Epoch [10/60], Batch [150/313], Loss: 1.6460
# Epoch [10/60], Batch [200/313], Loss: 1.6936
# Epoch [10/60], Batch [250/313], Loss: 1.6237
# Epoch [10/60], Batch [300/313], Loss: 1.6397
# Epoch 10 训练耗时：63.43秒
# Epoch 10 验证准确率：36.55%
# 最佳模型已保存（准确率：36.55%）
# Epoch [11/60], Batch [50/313], Loss: 1.6250
# Epoch [11/60], Batch [100/313], Loss: 1.6092
# Epoch [11/60], Batch [150/313], Loss: 1.6180
# Epoch [11/60], Batch [200/313], Loss: 1.6333
# Epoch [11/60], Batch [250/313], Loss: 1.5423
# Epoch [11/60], Batch [300/313], Loss: 1.6276
# Epoch 11 训练耗时：63.40秒
# Epoch 11 验证准确率：39.98%
# 最佳模型已保存（准确率：39.98%）
# Epoch [12/60], Batch [50/313], Loss: 1.5466
# Epoch [12/60], Batch [100/313], Loss: 1.5466
# Epoch [12/60], Batch [150/313], Loss: 1.5354
# Epoch [12/60], Batch [200/313], Loss: 1.5604
# Epoch [12/60], Batch [250/313], Loss: 1.5924
# Epoch [12/60], Batch [300/313], Loss: 1.5612
# Epoch 12 训练耗时：65.23秒
# Epoch 12 验证准确率：41.76%
# 最佳模型已保存（准确率：41.76%）
# Epoch [13/60], Batch [50/313], Loss: 1.5518
# Epoch [13/60], Batch [100/313], Loss: 1.5352
# Epoch [13/60], Batch [150/313], Loss: 1.5020
# Epoch [13/60], Batch [200/313], Loss: 1.5218
# Epoch [13/60], Batch [250/313], Loss: 1.5486
# Epoch [13/60], Batch [300/313], Loss: 1.4910
# Epoch 13 训练耗时：65.48秒
# Epoch 13 验证准确率：40.96%
# Epoch [14/60], Batch [50/313], Loss: 1.4979
# Epoch [14/60], Batch [100/313], Loss: 1.4380
# Epoch [14/60], Batch [150/313], Loss: 1.5400
# Epoch [14/60], Batch [200/313], Loss: 1.5255
# Epoch [14/60], Batch [250/313], Loss: 1.4999
# Epoch [14/60], Batch [300/313], Loss: 1.4433
# Epoch 14 训练耗时：66.87秒
# Epoch 14 验证准确率：42.67%
# 最佳模型已保存（准确率：42.67%）
# Epoch [15/60], Batch [50/313], Loss: 1.4702
# Epoch [15/60], Batch [100/313], Loss: 1.4182
# Epoch [15/60], Batch [150/313], Loss: 1.4916
# Epoch [15/60], Batch [200/313], Loss: 1.4287
# Epoch [15/60], Batch [250/313], Loss: 1.5069
# Epoch [15/60], Batch [300/313], Loss: 1.5073
# Epoch 15 训练耗时：63.42秒
# Epoch 15 验证准确率：43.24%
# 最佳模型已保存（准确率：43.24%）
# Epoch [16/60], Batch [50/313], Loss: 1.4629
# Epoch [16/60], Batch [100/313], Loss: 1.3957
# Epoch [16/60], Batch [150/313], Loss: 1.3705
# Epoch [16/60], Batch [200/313], Loss: 1.3908
# Epoch [16/60], Batch [250/313], Loss: 1.4177
# Epoch [16/60], Batch [300/313], Loss: 1.4490
# Epoch 16 训练耗时：65.75秒
# Epoch 16 验证准确率：42.62%
# Epoch [17/60], Batch [50/313], Loss: 1.4168
# Epoch [17/60], Batch [100/313], Loss: 1.3446
# Epoch [17/60], Batch [150/313], Loss: 1.4302
# Epoch [17/60], Batch [200/313], Loss: 1.3279
# Epoch [17/60], Batch [250/313], Loss: 1.3878
# Epoch [17/60], Batch [300/313], Loss: 1.3739
# Epoch 17 训练耗时：66.42秒
# Epoch 17 验证准确率：48.09%
# 最佳模型已保存（准确率：48.09%）
# Epoch [18/60], Batch [50/313], Loss: 1.3920
# Epoch [18/60], Batch [100/313], Loss: 1.3746
# Epoch [18/60], Batch [150/313], Loss: 1.2580
# Epoch [18/60], Batch [200/313], Loss: 1.3661
# Epoch [18/60], Batch [250/313], Loss: 1.3712
# Epoch [18/60], Batch [300/313], Loss: 1.3415
# Epoch 18 训练耗时：64.60秒
# Epoch 18 验证准确率：44.02%
# Epoch [19/60], Batch [50/313], Loss: 1.3469
# Epoch [19/60], Batch [100/313], Loss: 1.3426
# Epoch [19/60], Batch [150/313], Loss: 1.3925
# Epoch [19/60], Batch [200/313], Loss: 1.2668
# Epoch [19/60], Batch [250/313], Loss: 1.3296
# Epoch [19/60], Batch [300/313], Loss: 1.2918
# Epoch 19 训练耗时：73.62秒
# Epoch 19 验证准确率：48.76%
# 最佳模型已保存（准确率：48.76%）
# Epoch [20/60], Batch [50/313], Loss: 1.2857
# Epoch [20/60], Batch [100/313], Loss: 1.3369
# Epoch [20/60], Batch [150/313], Loss: 1.2815
# Epoch [20/60], Batch [200/313], Loss: 1.3101
# Epoch [20/60], Batch [250/313], Loss: 1.2528
# Epoch [20/60], Batch [300/313], Loss: 1.3061
# Epoch 20 训练耗时：46.26秒
# Epoch 20 验证准确率：49.15%
# 最佳模型已保存（准确率：49.15%）
# Epoch [21/60], Batch [50/313], Loss: 1.2240
# Epoch [21/60], Batch [100/313], Loss: 1.1871
# Epoch [21/60], Batch [150/313], Loss: 1.1838
# Epoch [21/60], Batch [200/313], Loss: 1.1549
# Epoch [21/60], Batch [250/313], Loss: 1.1329
# Epoch [21/60], Batch [300/313], Loss: 1.1999
# Epoch 21 训练耗时：53.62秒
# Epoch 21 验证准确率：54.04%
# 最佳模型已保存（准确率：54.04%）
# Epoch [22/60], Batch [50/313], Loss: 1.1363
# Epoch [22/60], Batch [100/313], Loss: 1.2016
# Epoch [22/60], Batch [150/313], Loss: 1.1547
# Epoch [22/60], Batch [200/313], Loss: 1.1506
# Epoch [22/60], Batch [250/313], Loss: 1.1695
# Epoch [22/60], Batch [300/313], Loss: 1.1195
# Epoch 22 训练耗时：61.55秒
# Epoch 22 验证准确率：53.94%
# Epoch [23/60], Batch [50/313], Loss: 1.1586
# Epoch [23/60], Batch [100/313], Loss: 1.1351
# Epoch [23/60], Batch [150/313], Loss: 1.1693
# Epoch [23/60], Batch [200/313], Loss: 1.1204
# Epoch [23/60], Batch [250/313], Loss: 1.1261
# Epoch [23/60], Batch [300/313], Loss: 1.1110
# Epoch 23 训练耗时：57.39秒
# Epoch 23 验证准确率：54.02%
# Epoch [24/60], Batch [50/313], Loss: 1.1483
# Epoch [24/60], Batch [100/313], Loss: 1.1915
# Epoch [24/60], Batch [150/313], Loss: 1.0993
# Epoch [24/60], Batch [200/313], Loss: 1.1509
# Epoch [24/60], Batch [250/313], Loss: 1.0917
# Epoch [24/60], Batch [300/313], Loss: 1.1050
# Epoch 24 训练耗时：60.58秒
# Epoch 24 验证准确率：54.62%
# 最佳模型已保存（准确率：54.62%）
# Epoch [25/60], Batch [50/313], Loss: 1.0906
# Epoch [25/60], Batch [100/313], Loss: 1.1291
# Epoch [25/60], Batch [150/313], Loss: 1.0940
# Epoch [25/60], Batch [200/313], Loss: 1.1021
# Epoch [25/60], Batch [250/313], Loss: 1.1477
# Epoch [25/60], Batch [300/313], Loss: 1.0677
# Epoch 25 训练耗时：57.12秒
# Epoch 25 验证准确率：54.60%
# Epoch [26/60], Batch [50/313], Loss: 1.1087
# Epoch [26/60], Batch [100/313], Loss: 1.1535
# Epoch [26/60], Batch [150/313], Loss: 1.0550
# Epoch [26/60], Batch [200/313], Loss: 1.1489
# Epoch [26/60], Batch [250/313], Loss: 1.0974
# Epoch [26/60], Batch [300/313], Loss: 1.1352
# Epoch 26 训练耗时：54.97秒
# Epoch 26 验证准确率：53.86%
# Epoch [27/60], Batch [50/313], Loss: 1.1251
# Epoch [27/60], Batch [100/313], Loss: 1.1105
# Epoch [27/60], Batch [150/313], Loss: 1.0983
# Epoch [27/60], Batch [200/313], Loss: 1.1082
# Epoch [27/60], Batch [250/313], Loss: 1.1262
# Epoch [27/60], Batch [300/313], Loss: 1.0878
# Epoch 27 训练耗时：57.89秒
# Epoch 27 验证准确率：54.48%
# Epoch [28/60], Batch [50/313], Loss: 1.0570
# Epoch [28/60], Batch [100/313], Loss: 1.0796
# Epoch [28/60], Batch [150/313], Loss: 1.1303
# Epoch [28/60], Batch [200/313], Loss: 1.1451
# Epoch [28/60], Batch [250/313], Loss: 1.0824
# Epoch [28/60], Batch [300/313], Loss: 1.0736
# Epoch 28 训练耗时：59.94秒
# Epoch 28 验证准确率：54.14%
# Epoch [29/60], Batch [50/313], Loss: 1.1012
# Epoch [29/60], Batch [100/313], Loss: 1.0371
# Epoch [29/60], Batch [150/313], Loss: 1.1234
# Epoch [29/60], Batch [200/313], Loss: 1.1111
# Epoch [29/60], Batch [250/313], Loss: 1.0774
# Epoch [29/60], Batch [300/313], Loss: 1.1489
# Epoch 29 训练耗时：61.98秒
# Epoch 29 验证准确率：55.73%
# 最佳模型已保存（准确率：55.73%）
# Epoch [30/60], Batch [50/313], Loss: 1.0433
# Epoch [30/60], Batch [100/313], Loss: 1.0905
# Epoch [30/60], Batch [150/313], Loss: 1.0462
# Epoch [30/60], Batch [200/313], Loss: 1.0659
# Epoch [30/60], Batch [250/313], Loss: 1.0931
# Epoch [30/60], Batch [300/313], Loss: 1.1018
# Epoch 30 训练耗时：62.25秒
# Epoch 30 验证准确率：55.89%
# 最佳模型已保存（准确率：55.89%）
# Epoch [31/60], Batch [50/313], Loss: 1.1012
# Epoch [31/60], Batch [100/313], Loss: 1.0735
# Epoch [31/60], Batch [150/313], Loss: 1.0257
# Epoch [31/60], Batch [200/313], Loss: 1.0578
# Epoch [31/60], Batch [250/313], Loss: 1.1581
# Epoch [31/60], Batch [300/313], Loss: 1.0572
# Epoch 31 训练耗时：56.62秒
# Epoch 31 验证准确率：56.31%
# 最佳模型已保存（准确率：56.31%）
# Epoch [32/60], Batch [50/313], Loss: 1.0351
# Epoch [32/60], Batch [100/313], Loss: 1.0991
# Epoch [32/60], Batch [150/313], Loss: 1.0333
# Epoch [32/60], Batch [200/313], Loss: 1.0551
# Epoch [32/60], Batch [250/313], Loss: 1.1285
# Epoch [32/60], Batch [300/313], Loss: 1.0791
# Epoch 32 训练耗时：56.34秒
# Epoch 32 验证准确率：56.95%
# 最佳模型已保存（准确率：56.95%）
# Epoch [33/60], Batch [50/313], Loss: 1.0410
# Epoch [33/60], Batch [100/313], Loss: 1.0867
# Epoch [33/60], Batch [150/313], Loss: 1.0239
# Epoch [33/60], Batch [200/313], Loss: 1.0596
# Epoch [33/60], Batch [250/313], Loss: 1.0535
# Epoch [33/60], Batch [300/313], Loss: 1.0559
# Epoch 33 训练耗时：63.81秒
# Epoch 33 验证准确率：57.46%
# 最佳模型已保存（准确率：57.46%）
# Epoch [34/60], Batch [50/313], Loss: 1.0583
# Epoch [34/60], Batch [100/313], Loss: 1.0252
# Epoch [34/60], Batch [150/313], Loss: 1.0478
# Epoch [34/60], Batch [200/313], Loss: 1.0848
# Epoch [34/60], Batch [250/313], Loss: 1.0578
# Epoch [34/60], Batch [300/313], Loss: 1.0263
# Epoch 34 训练耗时：53.36秒
# Epoch 34 验证准确率：57.05%
# Epoch [35/60], Batch [50/313], Loss: 1.0378
# Epoch [35/60], Batch [100/313], Loss: 1.0991
# Epoch [35/60], Batch [150/313], Loss: 1.0795
# Epoch [35/60], Batch [200/313], Loss: 1.0223
# Epoch [35/60], Batch [250/313], Loss: 1.0547
# Epoch [35/60], Batch [300/313], Loss: 1.0406
# Epoch 35 训练耗时：61.13秒
# Epoch 35 验证准确率：58.04%
# 最佳模型已保存（准确率：58.04%）
# Epoch [36/60], Batch [50/313], Loss: 1.0482
# Epoch [36/60], Batch [100/313], Loss: 1.0161
# Epoch [36/60], Batch [150/313], Loss: 1.0503
# Epoch [36/60], Batch [200/313], Loss: 1.0381
# Epoch [36/60], Batch [250/313], Loss: 0.9767
# Epoch [36/60], Batch [300/313], Loss: 1.0374
# Epoch 36 训练耗时：55.83秒
# Epoch 36 验证准确率：57.06%
# Epoch [37/60], Batch [50/313], Loss: 0.9953
# Epoch [37/60], Batch [100/313], Loss: 1.0310
# Epoch [37/60], Batch [150/313], Loss: 1.0365
# Epoch [37/60], Batch [200/313], Loss: 0.9715
# Epoch [37/60], Batch [250/313], Loss: 1.0930
# Epoch [37/60], Batch [300/313], Loss: 1.0404
# Epoch 37 训练耗时：50.88秒
# Epoch 37 验证准确率：57.33%
# Epoch [38/60], Batch [50/313], Loss: 1.0295
# Epoch [38/60], Batch [100/313], Loss: 1.0654
# Epoch [38/60], Batch [150/313], Loss: 1.0373
# Epoch [38/60], Batch [200/313], Loss: 1.0444
# Epoch [38/60], Batch [250/313], Loss: 0.9652
# Epoch [38/60], Batch [300/313], Loss: 1.0263
# Epoch 38 训练耗时：51.10秒
# Epoch 38 验证准确率：57.75%
# Epoch [39/60], Batch [50/313], Loss: 1.0070
# Epoch [39/60], Batch [100/313], Loss: 1.0038
# Epoch [39/60], Batch [150/313], Loss: 1.0246
# Epoch [39/60], Batch [200/313], Loss: 1.0178
# Epoch [39/60], Batch [250/313], Loss: 1.0550
# Epoch [39/60], Batch [300/313], Loss: 1.0226
# Epoch 39 训练耗时：54.48秒
# Epoch 39 验证准确率：58.42%
# 最佳模型已保存（准确率：58.42%）
# Epoch [40/60], Batch [50/313], Loss: 1.0334
# Epoch [40/60], Batch [100/313], Loss: 1.0065
# Epoch [40/60], Batch [150/313], Loss: 0.9743
# Epoch [40/60], Batch [200/313], Loss: 1.0022
# Epoch [40/60], Batch [250/313], Loss: 1.0378
# Epoch [40/60], Batch [300/313], Loss: 1.0288
# Epoch 40 训练耗时：50.86秒
# Epoch 40 验证准确率：59.16%
# 最佳模型已保存（准确率：59.16%）
# Epoch [41/60], Batch [50/313], Loss: 1.0246
# Epoch [41/60], Batch [100/313], Loss: 0.9738
# Epoch [41/60], Batch [150/313], Loss: 0.9495
# Epoch [41/60], Batch [200/313], Loss: 0.9809
# Epoch [41/60], Batch [250/313], Loss: 0.9093
# Epoch [41/60], Batch [300/313], Loss: 1.0343
# Epoch 41 训练耗时：53.58秒
# Epoch 41 验证准确率：59.24%
# 最佳模型已保存（准确率：59.24%）
# Epoch [42/60], Batch [50/313], Loss: 0.8946
# Epoch [42/60], Batch [100/313], Loss: 0.9373
# Epoch [42/60], Batch [150/313], Loss: 1.0141
# Epoch [42/60], Batch [200/313], Loss: 1.0193
# Epoch [42/60], Batch [250/313], Loss: 0.9639
# Epoch [42/60], Batch [300/313], Loss: 0.9962
# Epoch 42 训练耗时：49.77秒
# Epoch 42 验证准确率：59.59%
# 最佳模型已保存（准确率：59.59%）
# Epoch [43/60], Batch [50/313], Loss: 1.0070
# Epoch [43/60], Batch [100/313], Loss: 0.9244
# Epoch [43/60], Batch [150/313], Loss: 1.0033
# Epoch [43/60], Batch [200/313], Loss: 0.9458
# Epoch [43/60], Batch [250/313], Loss: 0.9659
# Epoch [43/60], Batch [300/313], Loss: 1.0201
# Epoch 43 训练耗时：56.05秒
# Epoch 43 验证准确率：59.61%
# 最佳模型已保存（准确率：59.61%）
# Epoch [44/60], Batch [50/313], Loss: 0.9678
# Epoch [44/60], Batch [100/313], Loss: 0.9404
# Epoch [44/60], Batch [150/313], Loss: 0.9761
# Epoch [44/60], Batch [200/313], Loss: 0.9469
# Epoch [44/60], Batch [250/313], Loss: 0.9875
# Epoch [44/60], Batch [300/313], Loss: 0.9560
# Epoch 44 训练耗时：61.62秒
# Epoch 44 验证准确率：58.91%
# Epoch [45/60], Batch [50/313], Loss: 0.9260
# Epoch [45/60], Batch [100/313], Loss: 0.9694
# Epoch [45/60], Batch [150/313], Loss: 0.9625
# Epoch [45/60], Batch [200/313], Loss: 0.9426
# Epoch [45/60], Batch [250/313], Loss: 0.9755
# Epoch [45/60], Batch [300/313], Loss: 0.9934
# Epoch 45 训练耗时：62.86秒
# Epoch 45 验证准确率：59.69%
# 最佳模型已保存（准确率：59.69%）
# Epoch [46/60], Batch [50/313], Loss: 0.9356
# Epoch [46/60], Batch [100/313], Loss: 0.9632
# Epoch [46/60], Batch [150/313], Loss: 0.9971
# Epoch [46/60], Batch [200/313], Loss: 0.9649
# Epoch [46/60], Batch [250/313], Loss: 0.9857
# Epoch [46/60], Batch [300/313], Loss: 0.9543
# Epoch 46 训练耗时：61.09秒
# Epoch 46 验证准确率：59.55%
# Epoch [47/60], Batch [50/313], Loss: 0.9352
# Epoch [47/60], Batch [100/313], Loss: 0.9824
# Epoch [47/60], Batch [150/313], Loss: 0.9530
# Epoch [47/60], Batch [200/313], Loss: 0.9781
# Epoch [47/60], Batch [250/313], Loss: 1.0024
# Epoch [47/60], Batch [300/313], Loss: 0.9419
# Epoch 47 训练耗时：61.94秒
# Epoch 47 验证准确率：59.33%
# Epoch [48/60], Batch [50/313], Loss: 1.0155
# Epoch [48/60], Batch [100/313], Loss: 0.9125
# Epoch [48/60], Batch [150/313], Loss: 0.9932
# Epoch [48/60], Batch [200/313], Loss: 0.9476
# Epoch [48/60], Batch [250/313], Loss: 0.9740
# Epoch [48/60], Batch [300/313], Loss: 1.0041
# Epoch 48 训练耗时：60.44秒
# Epoch 48 验证准确率：59.55%
# Epoch [49/60], Batch [50/313], Loss: 0.9730
# Epoch [49/60], Batch [100/313], Loss: 0.9235
# Epoch [49/60], Batch [150/313], Loss: 0.9709
# Epoch [49/60], Batch [200/313], Loss: 0.9076
# Epoch [49/60], Batch [250/313], Loss: 0.9876
# Epoch [49/60], Batch [300/313], Loss: 0.9334
# Epoch 49 训练耗时：60.98秒
# Epoch 49 验证准确率：59.90%
# 最佳模型已保存（准确率：59.90%）
# Epoch [50/60], Batch [50/313], Loss: 0.9393
# Epoch [50/60], Batch [100/313], Loss: 0.9918
# Epoch [50/60], Batch [150/313], Loss: 0.9442
# Epoch [50/60], Batch [200/313], Loss: 0.9606
# Epoch [50/60], Batch [250/313], Loss: 1.0047
# Epoch [50/60], Batch [300/313], Loss: 0.9688
# Epoch 50 训练耗时：56.24秒
# Epoch 50 验证准确率：59.33%
# Epoch [51/60], Batch [50/313], Loss: 0.9733
# Epoch [51/60], Batch [100/313], Loss: 0.9199
# Epoch [51/60], Batch [150/313], Loss: 0.9681
# Epoch [51/60], Batch [200/313], Loss: 0.9552
# Epoch [51/60], Batch [250/313], Loss: 0.9872
# Epoch [51/60], Batch [300/313], Loss: 0.9663
# Epoch 51 训练耗时：57.84秒
# Epoch 51 验证准确率：59.84%
# Epoch [52/60], Batch [50/313], Loss: 0.9348
# Epoch [52/60], Batch [100/313], Loss: 1.0022
# Epoch [52/60], Batch [150/313], Loss: 0.9828
# Epoch [52/60], Batch [200/313], Loss: 0.9172
# Epoch [52/60], Batch [250/313], Loss: 0.9174
# Epoch [52/60], Batch [300/313], Loss: 1.0011
# Epoch 52 训练耗时：61.21秒
# Epoch 52 验证准确率：59.94%
# 最佳模型已保存（准确率：59.94%）
# Epoch [53/60], Batch [50/313], Loss: 0.9832
# Epoch [53/60], Batch [100/313], Loss: 1.0024
# Epoch [53/60], Batch [150/313], Loss: 0.9258
# Epoch [53/60], Batch [200/313], Loss: 0.9814
# Epoch [53/60], Batch [250/313], Loss: 0.9346
# Epoch [53/60], Batch [300/313], Loss: 0.9287
# Epoch 53 训练耗时：58.68秒
# Epoch 53 验证准确率：60.20%
# 最佳模型已保存（准确率：60.20%）
# Epoch [54/60], Batch [50/313], Loss: 0.9348
# Epoch [54/60], Batch [100/313], Loss: 0.9446
# Epoch [54/60], Batch [150/313], Loss: 0.9887
# Epoch [54/60], Batch [200/313], Loss: 0.9307
# Epoch [54/60], Batch [250/313], Loss: 0.9949
# Epoch [54/60], Batch [300/313], Loss: 0.9212
# Epoch 54 训练耗时：58.02秒
# Epoch 54 验证准确率：59.39%
# Epoch [55/60], Batch [50/313], Loss: 0.9109
# Epoch [55/60], Batch [100/313], Loss: 0.9600
# Epoch [55/60], Batch [150/313], Loss: 0.9368
# Epoch [55/60], Batch [200/313], Loss: 1.0065
# Epoch [55/60], Batch [250/313], Loss: 0.9586
# Epoch [55/60], Batch [300/313], Loss: 0.9390
# Epoch 55 训练耗时：56.93秒
# Epoch 55 验证准确率：59.88%
# Epoch [56/60], Batch [50/313], Loss: 1.0174
# Epoch [56/60], Batch [100/313], Loss: 0.9528
# Epoch [56/60], Batch [150/313], Loss: 0.9687
# Epoch [56/60], Batch [200/313], Loss: 0.9911
# Epoch [56/60], Batch [250/313], Loss: 0.9107
# Epoch [56/60], Batch [300/313], Loss: 0.9426
# Epoch 56 训练耗时：59.27秒
# Epoch 56 验证准确率：59.88%
# Epoch [57/60], Batch [50/313], Loss: 0.9526
# Epoch [57/60], Batch [100/313], Loss: 0.9614
# Epoch [57/60], Batch [150/313], Loss: 0.9169
# Epoch [57/60], Batch [200/313], Loss: 0.9598
# Epoch [57/60], Batch [250/313], Loss: 0.9728
# Epoch [57/60], Batch [300/313], Loss: 0.9527
# Epoch 57 训练耗时：54.54秒
# Epoch 57 验证准确率：60.06%
# Epoch [58/60], Batch [50/313], Loss: 0.9794
# Epoch [58/60], Batch [100/313], Loss: 0.9972
# Epoch [58/60], Batch [150/313], Loss: 0.9457
# Epoch [58/60], Batch [200/313], Loss: 0.9529
# Epoch [58/60], Batch [250/313], Loss: 0.9433
# Epoch [58/60], Batch [300/313], Loss: 0.9327
# Epoch 58 训练耗时：54.08秒
# Epoch 58 验证准确率：59.92%
# Epoch [59/60], Batch [50/313], Loss: 0.9256
# Epoch [59/60], Batch [100/313], Loss: 0.9364
# Epoch [59/60], Batch [150/313], Loss: 0.9813
# Epoch [59/60], Batch [200/313], Loss: 0.9763
# Epoch [59/60], Batch [250/313], Loss: 0.9378
# Epoch [59/60], Batch [300/313], Loss: 0.9794
# Epoch 59 训练耗时：56.67秒
# Epoch 59 验证准确率：59.98%
# Epoch [60/60], Batch [50/313], Loss: 0.9170
# Epoch [60/60], Batch [100/313], Loss: 0.9251
# Epoch [60/60], Batch [150/313], Loss: 0.9560
# Epoch [60/60], Batch [200/313], Loss: 0.9521
# Epoch [60/60], Batch [250/313], Loss: 1.0114
# Epoch [60/60], Batch [300/313], Loss: 0.9789
# Epoch 60 训练耗时：56.91秒
# Epoch 60 验证准确率：60.17%
# 训练完毕！
# 最终最佳验证准确率：60.20%

# %%
# -------------------------- 6. 随机抽一张STL-10图片测试预测（修复类型错误） --------------------------
plt.rcParams["font.family"] = ["SimHei"]  # 兼容Windows和Linux的中文字体
plt.rcParams["axes.unicode_minus"] = False  # 确保负号正常显示
# 从验证集随机选一张图
dataset = val_dataset
if len(dataset) == 0:
    raise ValueError("验证集为空，请检查数据集加载是否正确！")

random_idx = random.randint(0, len(dataset) - 1)
img_tensor, true_label = dataset[random_idx]  # 注意：此时img已经是Tensor（因为val_dataset用了ToTensor()）

# 不需要再用val_transform处理（已经转换过了），直接增加批次维度并移到GPU
input_tensor = img_tensor.unsqueeze(0).to(device)  # 仅增加批次维度

# 加载最佳模型并预测
try:
    if not os.path.exists(save_path):
        raise FileNotFoundError(f"模型文件不存在：{save_path}")
    
    model.load_state_dict(torch.load(save_path, map_location=device))
    model.eval()
except Exception as e:
    print(f"模型加载失败：{str(e)}，使用当前模型演示")
    model.eval()

# 预测
with torch.no_grad():
    outputs = model(input_tensor)
    _, predicted_label = torch.max(outputs, 1)
    predicted_label = predicted_label.item()

# STL-10类别名称
class_names = [
    "airplane", "bird", "car", "cat", "deer",
    "dog", "horse", "monkey", "ship", "truck"
]

# 显示结果（需要将Tensor转回PIL Image才能显示）
# 先反标准化（因为val_transform做了Normalize，直接显示会失真）
inv_transform = transforms.Compose([
    transforms.Normalize(mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],  # 反标准化公式：x = x*std + mean → 逆操作：x = (x - mean)/std
                         std=[1/0.229, 1/0.224, 1/0.225]),
    transforms.ToPILImage()  # Tensor转PIL Image
])
img_pil = inv_transform(img_tensor)  # 转换为可显示的图片

plt.figure(figsize=(6, 6))
plt.imshow(img_pil)
is_correct = predicted_label == true_label
title_text = (
    f"真实标签: {class_names[true_label]} ({true_label})\n"
    f"预测标签: {class_names[predicted_label]} ({predicted_label})\n"
    f"结果: {'正确' if is_correct else '错误'}"
)
plt.title(title_text)
plt.axis("off")
plt.show()
